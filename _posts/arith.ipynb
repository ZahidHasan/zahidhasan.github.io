# %%
print(print(1.0 + 9.0==1.0))
# Out:
# False
# None

# %%
Zero Is Not “Nothing”
d= 9
x= 0
print(d/x)
# Out:
#   Cell In[17], line 1
#     Zero Is Not “Nothing”
#                 ^
# SyntaxError: invalid character '“' (U+201C)
